# %%
import pandas as pd
import glob
import os
import numpy as np
import geopandas as gpd

# %%
os.chdir('/mnt/c/Users/User/notebook/jupyterenv/generic-real-estate-consulting-project-18/')

# %%
SA2_shape = gpd.read_file("data/raw/shapefiles/SA2/SA2_2021_AUST_GDA2020.shp")
LGA_shape = gpd.read_file("data/raw/shapefiles/LGA/LGA_2022_AUST_GDA2020.shp")

# %%
SA2_shape.head()
# Out:
#   SA2_CODE21                       SA2_NAME21 CHG_FLAG21  CHG_LBL21  \
# 0  101021007                        Braidwood          0  No change
# 1  101021008                          Karabar          0  No change
# 2  101021009                       Queanbeyan          0  No change
# 3  101021010                Queanbeyan - East          0  No change
# 4  101021012  Queanbeyan West - Jerrabomberra          0  No change
#
#   SA3_CODE21  SA3_NAME21 SA4_CODE21      SA4_NAME21 GCC_CODE21   GCC_NAME21  \
# 0      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 1      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 2      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 3      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
# 4      10102  Queanbeyan        101  Capital Region      1RNSW  Rest of NSW
#
#   STE_CODE21       STE_NAME21 AUS_CODE21 AUS_NAME21  AREASQKM21  \
# ...

# %%
SA2_shape = SA2_shape[SA2_shape['STE_NAME21'] == 'Victoria']
SA2_shape.drop(SA2_shape.tail(2).index,inplace=True)

# %%
SA2_shape.drop(SA2_shape.iloc[:, 2:16], inplace=True, axis=1)

# %%
SA2_shape.rename(columns = {'SA2_CODE21':'SA2 code', 'SA2_NAME21':'SA2 name'}, inplace = True)

# %%
SA2_shape
# Out:
#        SA2 code             SA2 name  \
# 644   201011001            Alfredton
# 645   201011002             Ballarat
# 646   201011005            Buninyong
# 647   201011006            Delacombe
# 648   201011007        Smythes Creek
# ...         ...                  ...
# 1161  217031476                Otway
# 1162  217041477         Moyne - East
# 1163  217041478         Moyne - West
# 1164  217041479  Warrnambool - North
# 1165  217041480  Warrnambool - South
#
#                                                geometry
# 644   POLYGON ((143.78282 -37.56666, 143.75558 -37.5...
# 645   POLYGON ((143.81896 -37.55582, 143.81644 -37.5...
# 646   POLYGON ((143.84171 -37.61596, 143.84176 -37.6...
# 647   POLYGON ((143.75050 -37.59119, 143.75044 -37.5...
# 648   POLYGON ((143.73296 -37.62333, 143.73263 -37.6...
# ...                                                 ...
# 1161  MULTIPOLYGON (((143.40263 -38.78152, 143.40252...
# 1162  POLYGON ((142.41438 -38.09303, 142.41400 -38.0...
# ...

# %%
LGA_shape = LGA_shape[LGA_shape['STE_NAME21'] == 'Victoria']
LGA_shape.drop(LGA_shape.tail(2).index,inplace=True)

# %%
LGA_shape.drop(LGA_shape.iloc[:, 2:8], inplace=True, axis=1)

# %%
LGA_shape.rename(columns = {'LGA_CODE22':'LGA code', 'LGA_NAME22':'Local Government Area'}, inplace = True)

# %%
LGA_shape
# Out:
#     LGA code Local Government Area  SHAPE_Leng  SHAPE_Area  \
# 131    20110                Alpine    4.532210    0.483801
# 132    20260                Ararat    3.977757    0.428937
# 133    20570              Ballarat    1.651781    0.075296
# 134    20660               Banyule    0.582852    0.006392
# 135    20740            Bass Coast    2.908080    0.089421
# ..       ...                   ...         ...         ...
# 206    27260               Wyndham    1.293986    0.055520
# 207    27350                 Yarra    0.419875    0.001999
# 208    27450          Yarra Ranges    3.668577    0.252213
# 209    27630          Yarriambiack    5.443920    0.732179
# 210    29399    Unincorporated Vic    3.017305    0.029011
#
#                                               geometry
# 131  POLYGON ((146.67058 -36.56827, 146.67056 -36.5...
# 132  POLYGON ((142.71709 -37.15729, 142.71705 -37.1...
# 133  POLYGON ((143.86292 -37.38007, 143.85880 -37.4...
# ...

# %%
LGA_shape.to_csv("data/curated/shapefiles/LGA_Vic_pop_clean.csv")
SA2_shape.to_csv("data/curated/shapefiles/SA2_Vic_pop_clean.csv")
