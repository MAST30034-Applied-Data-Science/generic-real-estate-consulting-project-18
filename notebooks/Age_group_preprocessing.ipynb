# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/mnt/c/Users/User/notebook/jupyterenv/generic-real-estate-consulting-project-18/')

# %%
age_SA2 = pd.read_csv("data/raw/population/age_group/SA2_AGE_POP_csv.csv")
age_LGA = pd.read_csv("data/raw/population/age_group/LGA_AGE_POP_csv.csv")

# %%
age_SA2 = age_SA2[age_SA2['S/T name'] == 'Victoria']
age_SA2
# Out:
#       S/T code  S/T name GCCSA code    GCCSA name  SA4 code  \
# 642          2  Victoria      2RVIC  Rest of Vic.       201
# 643          2  Victoria      2RVIC  Rest of Vic.       201
# 644          2  Victoria      2RVIC  Rest of Vic.       201
# 645          2  Victoria      2RVIC  Rest of Vic.       201
# 646          2  Victoria      2RVIC  Rest of Vic.       201
# ...        ...       ...        ...           ...       ...
# 1159         2  Victoria      2RVIC  Rest of Vic.       217
# 1160         2  Victoria      2RVIC  Rest of Vic.       217
# 1161         2  Victoria      2RVIC  Rest of Vic.       217
# 1162         2  Victoria      2RVIC  Rest of Vic.       217
# 1163         2  Victoria      2RVIC  Rest of Vic.       217
#
#                         SA4 name  SA3 code             SA3 name   SA2 code  \
# 642                     Ballarat     20101             Ballarat  201011001
# 643                     Ballarat     20101             Ballarat  201011002
# ...

# %%
age_SA2.drop(age_SA2.iloc[:, 0:8], inplace=True, axis=1)
# Out:
# /tmp/ipykernel_233/295930571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_SA2.drop(age_SA2.iloc[:, 0:8], inplace=True, axis=1)

# %%
age_SA2
# Out:
#        SA2 code             SA2 name   0-4   5-9  10-14  15-19  20-24  25-29  \
# 642   201011001            Alfredton  1230  1388   1457   1318   1073    972
# 643   201011002             Ballarat   504   589    713    837    728    677
# 644   201011005            Buninyong   366   552    614    547    397    270
# 645   201011006            Delacombe   815   764    720    593    841   1069
# 646   201011007        Smythes Creek   228   298    378    346    213    147
# ...         ...                  ...   ...   ...    ...    ...    ...    ...
# 1159  217031476                Otway   151   168    200    168    109    157
# 1160  217041477         Moyne - East   426   470    508    441    330    351
# 1161  217041478         Moyne - West   516   611    729    588    389    424
# 1162  217041479  Warrnambool - North  1259  1434   1598   1424   1216   1463
# 1163  217041480  Warrnambool - South   641   695    728    713    673    892
#
# ...
