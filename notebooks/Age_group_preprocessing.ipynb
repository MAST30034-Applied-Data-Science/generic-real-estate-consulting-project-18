# %%
import pandas as pd
import numpy as np
import os

# %%
# set main directory
main_directory = os.getcwd().replace('/notebooks','')

# %%
age_SA2 = pd.read_csv(main_directory+"/data/raw/population/age_group/SA2_AGE_POP.csv")
age_LGA = pd.read_csv(main_directory+"/data/raw/population/age_group/LGA_AGE_POP.csv")

# %%
age_SA2 = age_SA2[age_SA2['S/T name'] == 'Victoria']
age_SA2
# Out:
#       S/T code  S/T name GCCSA code    GCCSA name  SA4 code  \
# 642          2  Victoria      2RVIC  Rest of Vic.       201
# 643          2  Victoria      2RVIC  Rest of Vic.       201
# 644          2  Victoria      2RVIC  Rest of Vic.       201
# 645          2  Victoria      2RVIC  Rest of Vic.       201
# 646          2  Victoria      2RVIC  Rest of Vic.       201
# ...        ...       ...        ...           ...       ...
# 1159         2  Victoria      2RVIC  Rest of Vic.       217
# 1160         2  Victoria      2RVIC  Rest of Vic.       217
# 1161         2  Victoria      2RVIC  Rest of Vic.       217
# 1162         2  Victoria      2RVIC  Rest of Vic.       217
# 1163         2  Victoria      2RVIC  Rest of Vic.       217
#
#                         SA4 name  SA3 code             SA3 name   SA2 code  \
# 642                     Ballarat     20101             Ballarat  201011001
# 643                     Ballarat     20101             Ballarat  201011002
# ...

# %%
age_SA2.drop(age_SA2.iloc[:, 0:8], inplace=True, axis=1)

# %%
age_SA2
# Out:
#        SA2 code             SA2 name   2001   2002   2003   2004   2005  \
# 642   201011001            Alfredton   5756   6092   6293   6480   6648
# 643   201011002             Ballarat  11497  11708  12015  12189  12269
# 644   201011005            Buninyong   5320   5399   5557   5620   5857
# 645   201011006            Delacombe   4154   4225   4371   4465   4704
# 646   201011007        Smythes Creek   3317   3378   3411   3473   3508
# ...         ...                  ...    ...    ...    ...    ...    ...
# 1159  217031476                Otway   3452   3479   3511   3511   3492
# 1160  217041477         Moyne - East   6718   6704   6676   6643   6638
# 1161  217041478         Moyne - West   8317   8387   8450   8487   8517
# 1162  217041479  Warrnambool - North  17053  17449  17726  17937  18172
# 1163  217041480  Warrnambool - South  12506  12578  12639  12697  12748
#
#        2006   2007   2008  ...   2016   2017   2018   2019   2020   2021  \
# ...
