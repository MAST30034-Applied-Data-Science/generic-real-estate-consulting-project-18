# %%
# import packages
import pandas as pd
import os

# %%
# set directory
main_directory = os.getcwd().strip('notebooks')
print(main_directory)
# Out:
# /Users/lucyliu/Applied_Data_Science/Project2_actual/

# %%
# import dataset. Dataset taken from 
# https://www.gen-agedcaredata.gov.au/Resources/Access-data/2019/September/Population-projections,-2017-(base)-to-2032-for-al
raw_data = pd.read_csv(main_directory +'data/raw/Victoria.csv')

# %%
# we only want the next three years
predictive_data = raw_data[(raw_data['YEAR'] == 2022)|(raw_data['YEAR'] == 2023) | (raw_data['YEAR'] == 2024) |(raw_data['YEAR'] == 2025)]

# %%
predictive_data
# Out:
#        YEAR   SA2_CODE             SA2_NAME      SEX  Age0-4  Age5-9  \
# 6930   2022  201011001            Alfredton     Male     596     625
# 6931   2022  201011001            Alfredton   Female     567     624
# 6932   2022  201011001            Alfredton  Persons    1163    1249
# 6933   2022  201011002             Ballarat     Male     278     325
# 6934   2022  201011002             Ballarat   Female     252     278
# ...     ...        ...                  ...      ...     ...     ...
# 12469  2025  217041479  Warrnambool - North   Female     668     693
# 12470  2025  217041479  Warrnambool - North  Persons    1378    1451
# 12471  2025  217041480  Warrnambool - South     Male     364     364
# 12472  2025  217041480  Warrnambool - South   Female     347     355
# 12473  2025  217041480  Warrnambool - South  Persons     711     719
#
#        Age10-14  Age15-19  Age20-24  Age25-29  ...  Age45-49  Age50-54  \
# ...
